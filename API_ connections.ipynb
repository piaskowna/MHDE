# %% [markdown]
# #### Companysearch

# %%
import requests
import json
from pprint import pprint


ACCESSTOKEN ='PUT_YOUR_TOKEN_HERE'
url = 'https://www.companyhouse.de/api/v1/company'

class BearerAuth(requests.auth.AuthBase):
    def __init__(self, token):
        self.token = token
    def __call__(self, r):
        r.headers["authorization"] = "Bearer " + self.token
        return r
    
query = "{company (query:\"%(query_string)s\") {name state country city zip street}}"
query = query % {"query_string": "PUT_YOUR_QUERY_HERE"} 

response = requests.post(url, auth=BearerAuth(ACCESSTOKEN), json={'query': query})

pprint(response.json())

# %% [markdown]
# As an example by querying "GmbH", we get the following output.

# %%
query = query % {"query_string": "GmbH"}
# Out:
# {'data': {'company': [{'city': 'Reutlingen',
#                        'country': 'DE',
#                        'name': 'GmbH',
#                        'state': None,
#                        'street': 'Wilhelmstr. 44',
#                        'zip': '72764'},
#                       {'city': 'Rosenheim',
#                        'country': None,
#                        'name': 'GmbH',
#                        'state': 'Rhineland-Palatinate',
#                        'street': None,
#                        'zip': None},
#                       {'city': 'München',
#                        'country': 'DE',
#                        'name': 'GmbH',
#                        'state': None,
#                        'street': 'Am Tucherpark 16',
#                        'zip': '80538'},
#                       {'city': None,
#                        'country': None,
#                        'name': '-GmbH',
#                        'state': None,
#                        'street': None,
#                        'zip': None},
#                       {'city': None,
#                        'country': None,
#                        'name': 'GmbH.',
#                        'state': None,
#                        'street': None,
#                        'zip': None},
#                       {'city': 'Ennepetal',
#                        'country': 'DE',
#                        'name': 'gGmbH',
#                        'state': 'North Rhine-Westphalia',
#                        'street': None,
#                        'zip': None},
#                       {'city': 'Essen',
#                        'country': 'DE',
#                        'name': 'IN GmbH',
#                        'state': 'North Rhine-Westphalia',
#                        'street': 'Niederfeldstr. 42',
#                        'zip': '45143'},
#                       {'city': 'Hemsbach',
#                        'country': 'DE',
#                        'name': 'addsignatur GmbH',
#                        'state': 'Baden-Württemberg',
#                        'street': 'Grünbergerstr. 64',
#                        'zip': '69502'},
#                       {'city': 'Wernigerode',
#                        'country': 'DE',
#                        'name': 'Harzer Schmalspurbahnen GmbH',
#                        'state': 'Saxony-Anhalt',
#                        'street': 'Friedrichstr. 151',
#                        'zip': '38855'},
#                       {'city': 'Langensalzwedel',
#                        'country': 'DE',
#                        'name': 'GmbH Läuferproduktion Langensalzwedel',
#                        'state': None,
#                        'street': 'Dorfstr. 33',
#                        'zip': '39590'},
#                       {'city': 'Laubach',
#                        'country': None,
#                        'name': 'mbH',
#                        'state': None,
#                        'street': None,
#                        'zip': None},
#                       {'city': 'Weißwasser',
#                        'country': 'DE',
#                        'name': 'K a r a GmbH',
#                        'state': 'Saxony',
#                        'street': 'Jahnstr. 76',
#                        'zip': 'O-758'},
#                       {'city': 'Hamburg',
#                        'country': 'DE',
#                        'name': 'GmbH Altstadt Grundstücksgesellschaft',
#                        'state': 'Hamburg',
#                        'street': 'Gerhart-Hauptmann-Pl. 50',
#                        'zip': '20095'},
#                       {'city': 'Wiesbaden',
#                        'country': 'DE',
#                        'name': 'MW Finance GmbH',
#                        'state': 'Hesse',
#                        'street': 'Bahnhofstr. 51-53',
#                        'zip': '65185'},
#                       {'city': 'Reutlingen',
#                        'country': 'DE',
#                        'name': 'MBH GmbH',
#                        'state': 'Baden-Württemberg',
#                        'street': 'Gerhard-Kindler-Str. 6',
#                        'zip': '72770'},
#                       {'city': 'Hamburg',
#                        'country': 'DE',
#                        'name': 'MBH Metal Brokers Hamburg GmbH',
#                        'state': 'Hamburg',
#                        'street': 'Neuer Wall 36',
#                        'zip': '20354'},
#                       {'city': 'Merzdorf',
#                        'country': 'DE',
#                        'name': 'MBH Merzdorf GmbH Maurer-Betonbauer-Handwerk',
#                        'state': 'Brandenburg',
#                        'street': 'Elsterwerdaerstr. 31C',
#                        'zip': '04932'},
#                       {'city': 'Hamburg',
#                        'country': 'DE',
#                        'name': 'GMBC RE GmbH',
#                        'state': 'Hamburg',
#                        'street': 'Kaiser-Wilhelm-Str. 93',
#                        'zip': '20355'},
#                       {'city': 'Düsseldorf',
#                        'country': 'DE',
#                        'name': 'Kaiserswerther Jugendhilfe gemeinnützige GmbH '
#                                '(gGmbH)',
#                        'state': None,
#                        'street': 'Alte Landstr. 179B',
#                        'zip': '40489'},
#                       {'city': 'Gerlingen',
#                        'country': 'DE',
#                        'name': 'GDBH GmbH',
#                        'state': 'Baden-Württemberg',
#                        'street': 'Panoramastr. 63',
#                        'zip': '70839'},
#                       {'city': 'Nordhorn',
#                        'country': 'DE',
#                        'name': 'GOPEA gemeinnützige GmbH (gGmbH)',
#                        'state': 'Lower Saxony',
#                        'street': 'Alfred-Mozer-Str. 26A',
#                        'zip': '48527'},
#                       {'city': 'Bremen',
#                        'country': 'DE',
#                        'name': 'Trauringgrosshandel GmbH',
#                        'state': 'Bremen',
#                        'street': 'Bahnhofstr. 3-4',
#                        'zip': '28195'},
#                       {'city': 'Hamburg',
#                        'country': 'DE',
#                        'name': 'GMBC Projects GmbH',
#                        'state': 'Hamburg',
#                        'street': 'Kaiser-Wilhelm-Str. 93',
#                        'zip': '20355'},
#                       {'city': 'Bad Oldesloe',
#                        'country': 'DE',
#                        'name': 'Horizonte GmbH',
#                        'state': 'Schleswig-Holstein',
#                        'street': 'Hagenstr. 12',
#                        'zip': '23843'},
#                       {'city': 'Kerpen',
#                        'country': 'DE',
#                        'name': 'Dest Events GmbH',
#                        'state': 'North Rhine-Westphalia',
#                        'street': 'Alfred-Nobel-Str. 11-13',
#                        'zip': '50169'},
#                       {'city': 'Stuttgart',
#                        'country': 'DE',
#                        'name': 'PROMOTION AKUT GmbH',
#                        'state': 'Baden-Württemberg',
#                        'street': 'Schockenriedstr. 17',
#                        'zip': '70565'},
#                       {'city': 'Malterdingen',
#                        'country': 'DE',
#                        'name': 'Octinity GmbH',
#                        'state': 'Baden-Württemberg',
#                        'street': 'Im Specken 9',
#                        'zip': '79364'},
#                       {'city': 'Mühltal',
#                        'country': 'DE',
#                        'name': "'Obitz GmbH'",
#                        'state': None,
#                        'street': 'Frankenhöhe 18',
#                        'zip': '64367'},
#                       {'city': 'Berlin',
#                        'country': 'DE',
#                        'name': 'Betreuungsfreunde GmbH',
#                        'state': 'Berlin',
#                        'street': 'Triftstr. 68',
#                        'zip': '13353'},
#                       {'city': 'Düsseldorf',
#                        'country': 'DE',
#                        'name': 'Elégance GmbH',
#                        'state': 'North Rhine-Westphalia',
#                        'street': 'Kennedydamm 24',
#                        'zip': '40476'},
#                       {'city': 'Freiburg im Breisgau',
#                        'country': 'DE',
#                        'name': 'forseo GmbH',
#                        'state': 'Baden-Württemberg',
#                        'street': 'Grünwälderstr. 10-14',
#                        'zip': '79098'},
#                       {'city': 'Hannover',
#                        'country': 'DE',
#                        'name': 'HörSys GmbH',
#                        'state': 'Lower Saxony',
#                        'street': 'Feodor-Lynen-Str. 35',
#                        'zip': '30625'},
#                       {'city': 'Oberursel (Taunus)',
#                        'country': None,
#                        'name': 'euroTech Study GmbH',
#                        'state': 'Hesse',
#                        'street': 'Ludwig-Erhard-Str. 16A',
#                        'zip': '61440'},
#                       {'city': 'March',
#                        'country': None,
#                        'name': 'Florath-Glasbau GmbH',
#                        'state': None,
#                        'street': 'Benzstr. 2-4',
#                        'zip': '79232'},
#                       {'city': 'Oschersleben OT Neindorf',
#                        'country': 'DE',
#                        'name': 'HELIOS Bördeklinik GmbH',
#                        'state': 'Saxony-Anhalt',
#                        'street': 'Krankenhaus 4',
#                        'zip': '39387'},
#                       {'city': 'Rostock',
#                        'country': 'DE',
#                        'name': 'Integral gemeinnützige GmbH',
#                        'state': 'Mecklenburg-Western Pomerania',
#                        'street': 'Augustenstr. 24',
#                        'zip': '18055'},
#                       {'city': 'Weinstadt',
#                        'country': None,
#                        'name': 'Tec-Select GmbH',
#                        'state': 'Baden-Württemberg',
#                        'street': 'Hauptstr. 112',
#                        'zip': '71384'},
#                       {'city': 'Hürth',
#                        'country': 'DE',
#                        'name': 'mesh GmbH',
#                        'state': 'North Rhine-Westphalia',
#                        'street': 'Otto Hahn Straße. 20A',
#                        'zip': '50354'},
#                       {'city': 'Schollbrunn',
#                        'country': 'DE',
#                        'name': 'Neu - Bethanien GmbH',
#                        'state': 'Bavaria',
#                        'street': 'Im Herrengrund 1',
#                        'zip': '97852'},
#                       {'city': 'Osterwieck',
#                        'country': 'DE',
#                        'name': 'TENMAT GmbH',
#                        'state': 'Saxony-Anhalt',
#                        'street': 'Ziegeleiweg 3',
#                        'zip': '38835'},
#                       {'city': 'Essen',
#                        'country': 'DE',
#                        'name': 'kulturimpuls gGmbH',
#                        'state': None,
#                        'street': 'Wandastr. 9',
#                        'zip': '45136'},
#                       {'city': 'Leipzig',
#                        'country': 'DE',
#                        'name': 'VILLA gGmbH',
#                        'state': 'Saxony',
#                        'street': 'Lessingstr. 7',
#                        'zip': '04109'},
#                       {'city': 'Berlin',
#                        'country': 'DE',
#                        'name': 'BHA Bayer GmbH',
#                        'state': 'Berlin',
#                        'street': 'Emserstr. 9 6 Og',
#                        'zip': '10719'},
#                       {'city': 'Radolfzell am Bodensee',
#                        'country': None,
#                        'name': 'Untersee Solar GmbH',
#                        'state': 'Baden-Württemberg',
#                        'street': 'Fritz-Reichle-Ring 4',
#                        'zip': '78315'},
#                       {'city': 'Annaberg-Buchholz',
#                        'country': 'DE',
#                        'name': 'Kreiskrankenhaus Stollberg gemeinnützige GmbH '
#                                'nach Firmenänderung: Erzgebirgsklinikum gGmbH)',
#                        'state': 'Saxony',
#                        'street': 'Chemnitzerstr. 15',
#                        'zip': '09456'},
#                       {'city': 'Nordhorn',
#                        'country': 'DE',
#                        'name': 'RSA der Jägerschaft Grafschaft Bentheim '
#                                'gemeinnützige GmbH (gGmbH)',
#                        'state': 'Lower Saxony',
#                        'street': 'Ootmarsumer Weg 38',
#                        'zip': '48527'},
#                       {'city': 'Bernburg (Sale)',
#                        'country': 'DE',
#                        'name': 'Zentrum für transkulturelle Psychotherapie '
#                                'gemeinnützige GmbH ("ZtP gGmbH")',
#                        'state': 'Saxony-Anhalt',
#                        'street': 'Dr.-John-Rittmeister-Str. 6',
#                        'zip': '06406'},
#                       {'city': 'Braunschweig',
#                        'country': 'DE',
#                        'name': '"Quadriga" Immobilienvermittlung GmbH',
#                        'state': 'Lower Saxony',
#                        'street': 'Ernst-Amme-Str. 24',
#                        'zip': '38114'},
#                       {'city': 'Leipzig',
#                        'country': 'DE',
#                        'name': '"Reisebüro Arcadia GmbH"',
#                        'state': None,
#                        'street': 'Martin-Luther-Ring 12',
#                        'zip': '04109'},
#                       {'city': 'Leverkusen',
#                        'country': 'DE',
#                        'name': "'AWO-Kita' GmbH",
#                        'state': 'North Rhine-Westphalia',
#                        'street': 'Königsbergerpl. 26',
#                        'zip': '51371'}]}}

# %% [markdown]
# #### Personsearch

# %%
import requests
import json
from pprint import pprint

ACCESSTOKEN ='PUT_YOUR_TOKEN_HERE'
URL = 'https://www.companyhouse.de/api/v1/person'

class BearerAuth(requests.auth.AuthBase):
    def __init__(self, token):
        self.token = token
    def __call__(self, r):
        r.headers["authorization"] = "Bearer " + self.token
        return r
    
query = "{person (query:\"%(query_string)s\") {name first_name birth_date city}}"
query = query % {"query_string": "PUT_YOUR_QUERY_HERE"}

response = requests.post(URL, auth=BearerAuth(ACCESSTOKEN), json={'query': query})
pprint(response.json())

# %% [markdown]
# As an example by querying "Schmidt", we get the following output.

# %%
query = query % {"query_string": "Schmidt"}
# Out:
# {'data': {'person': [{'birth_date': None,
#                       'city': None,
#                       'first_name': 'Schmidt',
#                       'name': 'Schmidt'},
#                      {'birth_date': None,
#                       'city': None,
#                       'first_name': 'A. Elmar',
#                       'name': 'Schmidt'},
#                      {'birth_date': None,
#                       'city': 'Velbert',
#                       'first_name': 'A.',
#                       'name': 'Schmidt'},
#                      {'birth_date': None,
#                       'city': None,
#                       'first_name': 'A.',
#                       'name': 'Schmidt'},
#                      {'birth_date': None,
#                       'city': None,
#                       'first_name': 'A.',
#                       'name': 'Schmidt-Burbach'},
#                      {'birth_date': None,
#                       'city': None,
#                       'first_name': 'A.',
#                       'name': 'Schmidt-Ewald'},
#                      {'birth_date': None,
#                       'city': 'Minden',
#                       'first_name': 'A.F.',
#                       'name': 'Schmidt'},
#                      {'birth_date': '1989-09-16',
#                       'city': 'Stendal',
#                       'first_name': 'Aaron',
#                       'name': 'Schmidtmann'},
#                      {'birth_date': '1977-10-03',
#                       'city': 'Wörth',
#                       'first_name': 'Achim Eugen',
#                       'name': 'Schmidt'},
#                      {'birth_date': '1954-04-20',
#                       'city': 'Rellingen',
#                       'first_name': 'Achim Franz Eckhard',
#                       'name': 'Schmidt'},
#                      {'birth_date': None,
#                       'city': None,
#                       'first_name': 'Achim Josef',
#                       'name': 'Schmidt'},
#                      {'birth_date': None,
#                       'city': 'Brechen',
#                       'first_name': 'Achim Josef',
#                       'name': 'Schmidt'},
#                      {'birth_date': None,
#                       'city': 'Steinberg',
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': None,
#                       'city': None,
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': '1943-12-10',
#                       'city': 'Albrechts',
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': '1963-04-11',
#                       'city': 'Rheinstetten',
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': '1949-08-17',
#                       'city': 'Oberelbert',
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': None,
#                       'city': None,
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': None,
#                       'city': 'Dinslaken',
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': '1943-10-10',
#                       'city': 'Neuwied',
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': None,
#                       'city': None,
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': '1960-03-29',
#                       'city': 'Geschäftsführer in Seßlach',
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': None,
#                       'city': None,
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': None,
#                       'city': None,
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': None,
#                       'city': None,
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': None,
#                       'city': 'Putlitz',
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': '1967-03-27',
#                       'city': 'Hüllhorst',
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': '1966-05-25',
#                       'city': 'Kottweiler-Schwanden',
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': '1964-02-29',
#                       'city': 'Bad Vilbel',
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': '1966-02-01',
#                       'city': 'Oftersheim',
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': '1969-10-13',
#                       'city': 'Köln',
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': None,
#                       'city': 'Köln',
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': '1977-02-11',
#                       'city': 'Forchheim',
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': '1955-04-29',
#                       'city': 'Mainz',
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': None,
#                       'city': None,
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': '1970-10-28',
#                       'city': 'München',
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': None,
#                       'city': 'Bruchköbel',
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': '1975-08-01',
#                       'city': 'Mülheim-Kärlich',
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': None,
#                       'city': None,
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': None,
#                       'city': 'Diplom-Landwirt',
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': None,
#                       'city': None,
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': None,
#                       'city': 'Bernburg',
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': '1962-10-11',
#                       'city': 'Herrenhof',
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': None,
#                       'city': None,
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': None,
#                       'city': 'Bühl',
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': None,
#                       'city': None,
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': '1956-10-14',
#                       'city': 'München',
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': '1983-08-11',
#                       'city': 'Hamburg',
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': '1958-08-28',
#                       'city': 'Mühlhausen',
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'},
#                      {'birth_date': None,
#                       'city': 'Hartmut Hastert',
#                       'first_name': 'Achim',
#                       'name': 'Schmidt'}]}}

# %% [markdown]
# #### Company network

# %%
import requests
import json
from pprint import pprint

ACCESSTOKEN ='PUT_YOUR_TOKEN_HERE'
url = 'https://www.companyhouse.de/api/v1/network'

class BearerAuth(requests.auth.AuthBase):
    def __init__(self, token):
        self.token = token
    def __call__(self, r):
        r.headers["authorization"] = "Bearer " + self.token
        return r
    
query ='''{node (id:\"%(id)s\", type: \"%(type)s\") {id uuid type company_name is_active city}
        edge {start_node end_node function_id function_name start_date end_date}}
      '''
query= query % {"id": "PUT_ID_HERE", "type": "company"}

response = requests.post(url, auth=BearerAuth(ACCESSTOKEN), json={'query': query})
pprint(response.json())

# %%
query= query % {"id": "e7e70a00-d3e4-11e4-b3ef-53b449010d08", "type": "company"}
# Out:
# {'data': {'edge': [{'end_date': '2020-08-07',
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2013-12-09',
#                     'start_node': 11868550},
#                    {'end_date': '2021-07-27',
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2017-07-06',
#                     'start_node': 6029274},
#                    {'end_date': '2020-12-14',
#                     'end_node': 8885522,
#                     'function_id': 2,
#                     'function_name': None,
#                     'start_date': '2011-05-26',
#                     'start_node': 6918259},
#                    {'end_date': None,
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2015-10-06',
#                     'start_node': 5352458},
#                    {'end_date': '2012-04-27',
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': None,
#                     'start_node': 8349975},
#                    {'end_date': '2002-06-11',
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2001-12-19',
#                     'start_node': 14778481},
#                    {'end_date': None,
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2011-09-13',
#                     'start_node': 8017515},
#                    {'end_date': '2014-01-22',
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2010-05-12',
#                     'start_node': 9184905},
#                    {'end_date': None,
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2015-10-06',
#                     'start_node': 15459766},
#                    {'end_date': '2003-01-24',
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2001-12-19',
#                     'start_node': 7358453},
#                    {'end_date': '2010-07-29',
#                     'end_node': 8885522,
#                     'function_id': 4,
#                     'function_name': None,
#                     'start_date': None,
#                     'start_node': 11559215},
#                    {'end_date': '2011-10-10',
#                     'end_node': 8885522,
#                     'function_id': 2,
#                     'function_name': None,
#                     'start_date': None,
#                     'start_node': 5651715},
#                    {'end_date': '2020-08-07',
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2018-02-08',
#                     'start_node': 14005199},
#                    {'end_date': '2021-03-25',
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2014-05-07',
#                     'start_node': 12367487},
#                    {'end_date': None,
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2009-06-10',
#                     'start_node': 9271924},
#                    {'end_date': '2006-05-26',
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': None,
#                     'start_node': 10554722},
#                    {'end_date': '2010-10-07',
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2002-11-27',
#                     'start_node': 14100504},
#                    {'end_date': None,
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2019-03-22',
#                     'start_node': 12020104},
#                    {'end_date': '2008-01-21',
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': None,
#                     'start_node': 15148656},
#                    {'end_date': '2002-06-11',
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2001-12-19',
#                     'start_node': 6829784},
#                    {'end_date': None,
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2006-08-28',
#                     'start_node': 4957623},
#                    {'end_date': '2019-11-29',
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2010-05-12',
#                     'start_node': 14100906},
#                    {'end_date': '2014-01-22',
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': None,
#                     'start_node': 6772284},
#                    {'end_date': None,
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2014-01-08',
#                     'start_node': 7031759},
#                    {'end_date': '2010-10-07',
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': None,
#                     'start_node': 14023440},
#                    {'end_date': None,
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2009-02-09',
#                     'start_node': 10122798},
#                    {'end_date': None,
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2018-11-16',
#                     'start_node': 13122991},
#                    {'end_date': None,
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2017-07-06',
#                     'start_node': 13367762},
#                    {'end_date': '2015-09-30',
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2013-08-06',
#                     'start_node': 14641327},
#                    {'end_date': '2018-02-08',
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2017-07-06',
#                     'start_node': 6369920},
#                    {'end_date': None,
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2016-11-28',
#                     'start_node': 4961121},
#                    {'end_date': '2010-05-12',
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2008-04-16',
#                     'start_node': 15284631},
#                    {'end_date': '2013-07-19',
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2007-08-01',
#                     'start_node': 12587993},
#                    {'end_date': '2010-10-07',
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2006-01-05',
#                     'start_node': 11625989},
#                    {'end_date': None,
#                     'end_node': 8885522,
#                     'function_id': 40,
#                     'function_name': None,
#                     'start_date': '2016-04-12',
#                     'start_node': 6726893},
#                    {'end_date': '2017-07-06',
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2007-08-02',
#                     'start_node': 12826995},
#                    {'end_date': '2006-01-05',
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': None,
#                     'start_node': 9111309},
#                    {'end_date': '2014-01-22',
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': None,
#                     'start_node': 8657313},
#                    {'end_date': None,
#                     'end_node': 8885522,
#                     'function_id': 2,
#                     'function_name': None,
#                     'start_date': '2009-06-10',
#                     'start_node': 11747303},
#                    {'end_date': '2021-01-26',
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2016-06-06',
#                     'start_node': 15086419},
#                    {'end_date': '2011-04-15',
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2009-02-09',
#                     'start_node': 11829483},
#                    {'end_date': '2017-04-11',
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2013-03-24',
#                     'start_node': 13120359},
#                    {'end_date': None,
#                     'end_node': 8885522,
#                     'function_id': 2,
#                     'function_name': None,
#                     'start_date': '2020-02-03',
#                     'start_node': 6990065},
#                    {'end_date': '2011-03-16',
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': None,
#                     'start_node': 5390778},
#                    {'end_date': '2019-11-29',
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': None,
#                     'start_node': 11633105},
#                    {'end_date': '2010-05-12',
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2001-12-19',
#                     'start_node': 10938518},
#                    {'end_date': '2020-08-07',
#                     'end_node': 8885522,
#                     'function_id': 2,
#                     'function_name': None,
#                     'start_date': '2010-11-12',
#                     'start_node': 6557854},
#                    {'end_date': '2016-06-06',
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2013-03-25',
#                     'start_node': 14380815},
#                    {'end_date': None,
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2021-04-28',
#                     'start_node': 6529837},
#                    {'end_date': None,
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2017-07-06',
#                     'start_node': 10498474},
#                    {'end_date': None,
#                     'end_node': 8885522,
#                     'function_id': 40,
#                     'function_name': None,
#                     'start_date': '2016-04-12',
#                     'start_node': 12999324},
#                    {'end_date': None,
#                     'end_node': 8885522,
#                     'function_id': 40,
#                     'function_name': None,
#                     'start_date': '2016-04-12',
#                     'start_node': 13003737},
#                    {'end_date': '2016-06-06',
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2014-01-08',
#                     'start_node': 12023931},
#                    {'end_date': None,
#                     'end_node': 8885522,
#                     'function_id': 2,
#                     'function_name': None,
#                     'start_date': '2020-02-03',
#                     'start_node': 14800082},
#                    {'end_date': None,
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2003-01-03',
#                     'start_node': 9556412},
#                    {'end_date': None,
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': '2012-01-25',
#                     'start_node': 6606745},
#                    {'end_date': '2007-04-05',
#                     'end_node': 8885522,
#                     'function_id': 30,
#                     'function_name': None,
#                     'start_date': None,
#                     'start_node': 8715014},
#                    {'end_date': '2014-06-29',
#                     'end_node': 8885522,
#                     'function_id': 87,
#                     'function_name': None,
#                     'start_date': '2013-12-30',
#                     'start_node': 4816877},
#                    {'end_date': '2018-06-29',
#                     'end_node': 8885522,
#                     'function_id': 87,
#                     'function_name': None,
#                     'start_date': '2017-12-30',
#                     'start_node': 14334004}],
#           'node': [{'city': None,
#                     'company_name': 'SCHUFA Holding AG',
#                     'id': 8885522,
#                     'is_active': True,
#                     'type': 'Company',
#                     'uuid': 'e7e70a00-d3e4-11e4-b3ef-53b449010d08'},
#                    {'city': 'Hofheim am Taunus',
#                     'company_name': None,
#                     'id': 11868550,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': 'fa901c40-d935-11e4-a891-53b449010d08'},
#                    {'city': 'Eppertshausen',
#                     'company_name': None,
#                     'id': 6029274,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '2cfa67d0-306f-11e6-b552-b16bd0367008'},
#                    {'city': 'Darmstadt',
#                     'company_name': None,
#                     'id': 6918259,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '9ec88a61-d93e-11e4-a891-53b449010d08'},
#                    {'city': 'Steinheim an der Murr',
#                     'company_name': None,
#                     'id': 5352458,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': 'fc671570-d951-11e4-a891-53b449010d08'},
#                    {'city': 'Neuss',
#                     'company_name': None,
#                     'id': 8349975,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': 'e59aabc0-d944-11e4-a891-53b449010d08'},
#                    {'city': 'Göppingen',
#                     'company_name': None,
#                     'id': 14778481,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': 'fbad9894-d995-11e4-a891-53b449010d08'},
#                    {'city': 'Frankfurt am Main',
#                     'company_name': None,
#                     'id': 8017515,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': 'df495590-d94a-11e4-a891-53b449010d08'},
#                    {'city': 'Frankfurt am Main',
#                     'company_name': None,
#                     'id': 9184905,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': 'e2735e00-31d7-11e6-b552-b16bd0367008'},
#                    {'city': 'Düsseldorf',
#                     'company_name': None,
#                     'id': 15459766,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': 'ced1a931-d952-11e4-a891-53b449010d08'},
#                    {'city': 'Bremen',
#                     'company_name': None,
#                     'id': 7358453,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': 'd4d295d0-d996-11e4-a891-53b449010d08'},
#                    {'city': 'Königswinter',
#                     'company_name': None,
#                     'id': 11559215,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': 'db02cce0-3656-11e6-b9a0-b16bd0367008'},
#                    {'city': 'Rüdesheim am Rhein',
#                     'company_name': None,
#                     'id': 5651715,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': 'ce15b260-d935-11e4-a891-53b449010d08'},
#                    {'city': 'Geisenheim',
#                     'company_name': None,
#                     'id': 14005199,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': 'cc17f1f0-1238-11e8-8c9e-e75d55bcca24'},
#                    {'city': 'Haan',
#                     'company_name': None,
#                     'id': 12367487,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': 'c97f2b50-3488-11e6-80a2-b16bd0367008'},
#                    {'city': 'Essen',
#                     'company_name': None,
#                     'id': 9271924,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': 'bed50e22-d937-11e4-a891-53b449010d08'},
#                    {'city': 'Kleinblittersdorf',
#                     'company_name': None,
#                     'id': 10554722,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': 'c2057472-d961-11e4-a891-53b449010d08'},
#                    {'city': 'Sankt Augustin',
#                     'company_name': None,
#                     'id': 14100504,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': 'ae75b610-79f0-11e5-af45-299f943b296d'},
#                    {'city': 'Lorch',
#                     'company_name': None,
#                     'id': 12020104,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': 'b1bce190-7015-11e8-9543-e7cc0fabb1c9'},
#                    {'city': 'Berlin',
#                     'company_name': None,
#                     'id': 15148656,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': 'aa730401-d946-11e4-a891-53b449010d08'},
#                    {'city': 'Oberaula',
#                     'company_name': None,
#                     'id': 6829784,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': 'a4017c04-d996-11e4-a891-53b449010d08'},
#                    {'city': 'Beltheim',
#                     'company_name': None,
#                     'id': 4957623,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': 'aa231110-3148-11e6-b552-b16bd0367008'},
#                    {'city': 'Nürnberg',
#                     'company_name': None,
#                     'id': 14100906,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '9ac5e9b1-d945-11e4-a891-53b449010d08'},
#                    {'city': 'Mainz',
#                     'company_name': None,
#                     'id': 6772284,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '8da9673a-93e4-40e4-b6d9-bb35b43b35a9'},
#                    {'city': 'Karlsruhe',
#                     'company_name': None,
#                     'id': 7031759,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '94ef9da1-d950-11e4-a891-53b449010d08'},
#                    {'city': 'München',
#                     'company_name': None,
#                     'id': 14023440,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '8a935273-d996-11e4-a891-53b449010d08'},
#                    {'city': 'Frankfurt am Main',
#                     'company_name': None,
#                     'id': 10122798,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '87a7fd82-d942-11e4-a891-53b449010d08'},
#                    {'city': 'Frankfurt am Main',
#                     'company_name': None,
#                     'id': 13122991,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '7bf3fce0-711c-11e7-a2fa-7125266151e9'},
#                    {'city': 'Wiesbaden',
#                     'company_name': None,
#                     'id': 13367762,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '78ad29c0-628b-11e7-85a0-db575e090cb3'},
#                    {'city': 'Olching',
#                     'company_name': None,
#                     'id': 14641327,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '7a654700-35b1-11e6-b9a0-b16bd0367008'},
#                    {'city': 'Fürth',
#                     'company_name': None,
#                     'id': 6369920,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '78172b50-628b-11e7-85a0-db575e090cb3'},
#                    {'city': 'Hillscheid',
#                     'company_name': None,
#                     'id': 4961121,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '7738c810-b5ca-11e6-afef-79d09fc497c1'},
#                    {'city': 'Wiesbaden',
#                     'company_name': None,
#                     'id': 15284631,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '7697fb01-d945-11e4-a891-53b449010d08'},
#                    {'city': 'Hofheim am Taunus',
#                     'company_name': None,
#                     'id': 12587993,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '6c409d02-d937-11e4-a891-53b449010d08'},
#                    {'city': 'Appenheim',
#                     'company_name': None,
#                     'id': 11625989,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '6cc92df2-d937-11e4-a891-53b449010d08'},
#                    {'city': 'Erftstadt',
#                     'company_name': None,
#                     'id': 6726893,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '75ceb6c1-d975-11e4-a891-53b449010d08'},
#                    {'city': 'Frankfurt am Main',
#                     'company_name': None,
#                     'id': 12826995,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '6a3965e0-d938-11e4-a891-53b449010d08'},
#                    {'city': 'Hamburg',
#                     'company_name': None,
#                     'id': 9111309,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '695e5870-d996-11e4-a891-53b449010d08'},
#                    {'city': 'Köln',
#                     'company_name': None,
#                     'id': 8657313,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '5e498130-d964-11e4-a891-53b449010d08'},
#                    {'city': 'Wiesbaden',
#                     'company_name': None,
#                     'id': 11747303,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '5aefabd2-d938-11e4-a891-53b449010d08'},
#                    {'city': 'Bonn',
#                     'company_name': None,
#                     'id': 15086419,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '62126600-aa74-11e6-b555-79d09fc497c1'},
#                    {'city': 'Wiesbaden',
#                     'company_name': None,
#                     'id': 11829483,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '46ec2850-d93a-11e4-a891-53b449010d08'},
#                    {'city': 'Weilerswist',
#                     'company_name': None,
#                     'id': 13120359,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '496bf160-d966-11e4-a891-53b449010d08'},
#                    {'city': 'Oberursel (Taunus)',
#                     'company_name': None,
#                     'id': 6990065,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '4673e190-aab9-11e6-b555-79d09fc497c1'},
#                    {'city': 'Wiesbaden',
#                     'company_name': None,
#                     'id': 5390778,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '055126a0-d946-11e4-a891-53b449010d08'},
#                    {'city': 'Essen',
#                     'company_name': None,
#                     'id': 11633105,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '0a820291-d949-11e4-a891-53b449010d08'},
#                    {'city': 'Mainz',
#                     'company_name': None,
#                     'id': 10938518,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '0e18430a-2381-41aa-afb2-d62edab76562'},
#                    {'city': 'Hamburg',
#                     'company_name': None,
#                     'id': 6557854,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '22bf1fd0-d941-11e4-a891-53b449010d08'},
#                    {'city': 'München',
#                     'company_name': None,
#                     'id': 14380815,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '16e92e10-3031-11e6-b552-b16bd0367008'},
#                    {'city': 'Wiesbaden',
#                     'company_name': None,
#                     'id': 6529837,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '131160df-a538-47b9-b6fe-228dafb02f97'},
#                    {'city': 'Frankfurt',
#                     'company_name': None,
#                     'id': 10498474,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '2a1c50a0-d94f-11e4-a891-53b449010d08'},
#                    {'city': 'Wiesbaden',
#                     'company_name': None,
#                     'id': 12999324,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '2d95e250-04c7-11e7-a804-79d09fc497c1'},
#                    {'city': 'Wiesbaden',
#                     'company_name': None,
#                     'id': 13003737,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '2db1f5d0-04c7-11e7-a804-79d09fc497c1'},
#                    {'city': 'Köln',
#                     'company_name': None,
#                     'id': 12023931,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '32e8b4c0-d950-11e4-a891-53b449010d08'},
#                    {'city': 'Wiesbaden',
#                     'company_name': None,
#                     'id': 14800082,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '399fa740-7c49-11e6-8f73-79d09fc497c1'},
#                    {'city': 'Taunusstein',
#                     'company_name': None,
#                     'id': 9556412,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '37a952a3-d967-11e4-a891-53b449010d08'},
#                    {'city': 'Eggenstein-Leopoldshafen',
#                     'company_name': None,
#                     'id': 6606745,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '43bed5f0-93b2-11e5-a63a-299f943b296d'},
#                    {'city': 'Stuttgart',
#                     'company_name': None,
#                     'id': 8715014,
#                     'is_active': True,
#                     'type': 'Person',
#                     'uuid': '444ad414-d93b-11e4-a891-53b449010d08'},
#                    {'city': None,
#                     'company_name': 'Rödl & Partner GmbH '
#                                     'Wirtschaftsprüfungsgesellschaft '
#                                     'Steuerberatungsgesellschaft',
#                     'id': 4816877,
#                     'is_active': True,
#                     'type': 'Company',
#                     'uuid': '85adc250-d3eb-11e4-b3ef-53b449010d08'},
#                    {'city': None,
#                     'company_name': 'Ernst & Young GmbH '
#                                     'Wirtschaftsprüfungsgesellschaft, '
#                                     'Zweigniederlassung Stuttgart',
#                     'id': 14334004,
#                     'is_active': True,
#                     'type': 'Company',
#                     'uuid': '4c75cb00-dec1-11e4-9dbc-53b449010d08'}]}}

# %% [markdown]
# #### Person network

# %%
import requests
import json
from pprint import pprint

ACCESSTOKEN ='PUT_YOUR_TOKEN_HERE'
url = 'https://www.companyhouse.de/api/v1/network'

class BearerAuth(requests.auth.AuthBase):
    def __init__(self, token):
        self.token = token
    def __call__(self, r):
        r.headers["authorization"] = "Bearer " + self.token
        return r
    
query ='''{node (id:\"%(id)s\", type: \"%(type)s\") {id uuid type is_active first_name last_name birth_date 
city} edge {start_node end_node function_id function_name start_date end_date}}
      '''

query= query % {"id":"PUT_ID_HERE", "type": "person"}

response = requests.post(url, auth=BearerAuth(ACCESSTOKEN), json={'query': query})
pprint(esponse.json())

# %% [markdown]
# As an example by querying id, we get the following output.

# %%
query= query % {"id":"e7884560-3149-11e6-b552-b16bd0367008", "type": "person"}
# Out:
# {'data': {'edge': [{'end_date': None,
#                     'end_node': 11833853,
#                     'function_id': 1,
#                     'function_name': None,
#                     'start_date': '1997-12-23',
#                     'start_node': 12089774}],
#           'node': [{'birth_date': '1941-09-18',
#                     'city': 'Bremen',
#                     'first_name': 'Alexander',
#                     'id': 12089774,
#                     'is_active': True,
#                     'last_name': 'Boshilow',
#                     'type': 'Person',
#                     'uuid': 'e7884560-3149-11e6-b552-b16bd0367008'},
#                    {'birth_date': None,
#                     'city': None,
#                     'first_name': None,
#                     'id': 11833853,
#                     'is_active': True,
#                     'last_name': None,
#                     'type': 'Company',
#                     'uuid': 'ac0dd020-2dd1-11e6-ac52-b16bd0367008'}]}}
